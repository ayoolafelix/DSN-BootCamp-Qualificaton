# %% [markdown]
# <a href="https://colab.research.google.com/github/ayoolafelix/DSN-BootCamp-Qualificaton/blob/master/DSN_Bootcamp_Qualification_2020_Pycaret_0_841097008975645.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#!pip install pycaret
from pycaret.classification import *
import numpy as np
import pandas as pd
import matplotlib as mpl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display


import warnings
warnings.filterwarnings("ignore")

# Set all options
# %matplotlib inline
plt.style.use('seaborn-notebook')
plt.rcParams["figure.figsize"] = (20, 3)
pd.options.display.float_format = '{:20,.4f}'.format
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
sns.set(context="paper", font="monospace")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
test = pd.read_csv('/content/gdrive/My Drive/DSN BootCamp Qualification/Test.csv')
train = pd.read_csv('/content/gdrive/My Drive/DSN BootCamp Qualification/Train.csv')
sample = pd.read_csv('/content/gdrive/My Drive/DSN BootCamp Qualification/SampleSubmission.csv')

# %%
train.set_index('Applicant_ID', inplace = True)
test.set_index('Applicant_ID', inplace = True)

# %%
print('Train dataset has {} entries and {} features'.format(train.shape[0], train.shape[1]))
print('Test dataset has {} entries and {} features'.format(test.shape[0], test.shape[1]))
print("We are predicting '{}'".format(train.columns[-1]))
# Out:
# Train dataset has 56000 entries and 51 features
# Test dataset has 24000 entries and 50 features
# We are predicting 'default_status'

# %%
train.head()
# Out:
#                        form_field1          form_field2          form_field3  \
# Applicant_ID
# Apcnt_1000000           3,436.0000               0.2851               1.6560
# Apcnt_1000004           3,456.0000               0.6740               0.2342
# Apcnt_1000008           3,276.0000               0.5384               3.1510
# Apcnt_1000012           3,372.0000               0.1701               0.5050
# Apcnt_1000016           3,370.0000               0.7727               1.1010
#
#                        form_field4          form_field5          form_field6  \
# Applicant_ID
# Apcnt_1000000               0.0000               0.0000               0.0000
# Apcnt_1000004               0.0000               0.0000               0.0000
# Apcnt_1000008               0.0000               6.2820                  nan
# Apcnt_1000012               0.0000               0.0000         192,166.0000
# Apcnt_1000016               0.0000               0.0000           1,556.0000
#
#                        form_field7          form_field8          form_field9  \
# Applicant_ID
# Apcnt_1000000      10,689,720.0000         252,072.0000       4,272,776.0000
# Apcnt_1000004         898,979.0000         497,531.0000       9,073,814.0000
# Apcnt_1000008         956,940.0000                  nan         192,944.0000
# Apcnt_1000012       3,044,703.0000         385,499.0000       3,986,472.0000
# Apcnt_1000016         214,728.0000         214,728.0000       1,284,089.0000
#
#                       form_field10         form_field11         form_field12  \
# Applicant_ID
# Apcnt_1000000      11,333,126.0000       4,397,256.0000       2,301,324.0000
# Apcnt_1000004       2,533,168.0000         244,292.0000       3,982,971.0000
# Apcnt_1000008       1,079,864.0000                  nan                  nan
# Apcnt_1000012       3,621,979.0000                  nan         771,776.0000
# Apcnt_1000016         361,770.0000         396,391.0000         818,456.0000
#
#                       form_field13  form_field14         form_field15  \
# Applicant_ID
# Apcnt_1000000       7,875,694.0000      96375139     112,181,765.0000
# Apcnt_1000004       2,141,445.0000      28141427      45,169,902.0000
# Apcnt_1000008               0.0000      16576457      22,452,691.0000
# Apcnt_1000012       1,186,839.0000      48187375     136,297,820.0000
# Apcnt_1000016         511,535.0000      28141427      15,292,757.0000
#
#                       form_field16         form_field17         form_field18  \
# Applicant_ID
# Apcnt_1000000               1.0000               1.0000               1.0000
# Apcnt_1000004               1.0000               1.0000               1.0000
# Apcnt_1000008                  nan                  nan                  nan
# Apcnt_1000012               0.0000               0.0000               0.0000
# Apcnt_1000016               0.0000               0.0000               0.0000
#
#                       form_field19         form_field20         form_field21  \
# Applicant_ID
# Apcnt_1000000               3.0000               3.0000             134.6550
# Apcnt_1000004               2.0000               2.0000             109.2300
# Apcnt_1000008               0.0000               0.0000                  nan
# Apcnt_1000012               1.0000               1.0000             120.1200
# Apcnt_1000016               3.0000               3.0000             104.5350
#
#                       form_field22         form_field23         form_field24  \
# Applicant_ID
# Apcnt_1000000                  nan                  nan             134.6550
# Apcnt_1000004          11,385.2400          14,584.2900              86.6850
# Apcnt_1000008                  nan                  nan                  nan
# Apcnt_1000012           8,580.0000               0.0000              85.8000
# Apcnt_1000016           8,360.1900          10,326.4500             115.3350
#
#                       form_field25         form_field26         form_field27  \
# Applicant_ID
# Apcnt_1000000           4,000.5000          17,064.0000          11,376.0000
# Apcnt_1000004           4,161.0000          13,413.0000           8,942.0000
# Apcnt_1000008           1,597.5000           4,746.0000           3,164.0000
# Apcnt_1000012           1,701.0000           4,014.0000           2,676.0000
# Apcnt_1000016           1,551.0000           3,285.0000           2,190.0000
#
#                       form_field28         form_field29         form_field30  \
# Applicant_ID
# Apcnt_1000000              60.0000          17,064.0000           5,962.0000
# Apcnt_1000004             304.0000          13,413.0000           5,780.0000
# Apcnt_1000008              60.0000          15,696.0000                  nan
# Apcnt_1000012              60.0000          11,679.0000                  nan
# Apcnt_1000016              60.0000          19,437.0000          12,958.0000
#
#                       form_field31         form_field32         form_field33  \
# Applicant_ID
# Apcnt_1000000                  nan           1,052.0000               8.0000
# Apcnt_1000004                  nan           2,554.0000              17.5000
# Apcnt_1000008          14,508.0000              70.0000               0.6666
# Apcnt_1000012                  nan             522.0000               7.8334
# Apcnt_1000016           5,202.0000             272.0000               1.0000
#
#                       form_field34         form_field35         form_field36  \
# Applicant_ID
# Apcnt_1000000               2.0000                  nan              12.0000
# Apcnt_1000004               0.0000               0.0000              16.0000
# Apcnt_1000008               0.0000                  nan              12.0000
# Apcnt_1000012               1.0000               1.0000               4.0000
# Apcnt_1000016               0.0000               0.0000              24.0000
#
#                       form_field37         form_field38         form_field39  \
# Applicant_ID
# Apcnt_1000000              12.0000               4.0000               0.0000
# Apcnt_1000004              24.0000               8.0000               0.0000
# Apcnt_1000008               0.0000               6.0000               0.0000
# Apcnt_1000012               8.0000               4.0000               1.0000
# Apcnt_1000016               2.0000              24.0000               0.0000
#
#                       form_field40         form_field41         form_field42  \
# Applicant_ID
# Apcnt_1000000                  nan                  nan               0.3929
# Apcnt_1000004                  nan                  nan               0.3143
# Apcnt_1000008             149.6805                  nan               0.1630
# Apcnt_1000012                  nan                  nan               0.4889
# Apcnt_1000016             150.0135                  nan               0.2750
#
#                       form_field43         form_field44         form_field45  \
# Applicant_ID
# Apcnt_1000000               2.0200               0.7116               0.0000
# Apcnt_1000004               8.0800               0.1836                  nan
# Apcnt_1000008              18.1800               0.7911               0.0000
# Apcnt_1000012               2.0200               0.6852                  nan
# Apcnt_1000016              12.1200               0.4382               0.0000
#
#                       form_field46 form_field47         form_field48  \
# Applicant_ID
# Apcnt_1000000               0.0000       charge                  nan
# Apcnt_1000004               0.0000       charge             349.8057
# Apcnt_1000008               0.0000       charge                  nan
# Apcnt_1000012               0.0000       charge              89.9401
# Apcnt_1000016               0.0000       charge              97.8875
#
#                       form_field49         form_field50 default_status
# Applicant_ID
# Apcnt_1000000               1.1295               0.0443             no
# Apcnt_1000004               1.6205               0.3224             no
# Apcnt_1000008               1.5134               0.0116            yes
# Apcnt_1000012               0.6645               0.0827             no
# Apcnt_1000016               1.4279               0.0456             no

# %%
plt.figure(figsize=(6,3))
sns.countplot(x= train.columns[-1] ,data=train)
plt.show()

# %%
def quality_report(df):
    """
    Description: Displays quality of data in terms of missing values, unique numbers, datatypes etc.
    Arguments: Dataframe
    """
    dtypes = df.dtypes
    nuniq = df.T.apply(lambda x: x.nunique(), axis=1)
    total = df.isnull().sum().sort_values(ascending = False)
    percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
    quality_df  = pd.concat([total, percent, nuniq, dtypes], axis=1, keys=['Total', 'Percent','Nunique', 'Dtype'])
    display(quality_df)


def object_count_plot(df):
    """
    Description : Plot countplot for all categorical features present in the dataframe passed
    Argument : Dataframe
    """
    
    for var in df.columns:
        if df[var].dtype == 'object':
            print(df[var].value_counts())
            plt.figure(figsize=(12,5))
            g = sns.countplot(x=var,data=df)
            g.set_xticklabels(g.get_xticklabels(), rotation=90, ha="right")
            plt.tight_layout()
            plt.show()
            
def numeric_distribution_plot(df):
    """
    Description : Gives distribution plot for all the numeric features in the dataframe passed
    Argument : Dataframe
    """
    for col in df.columns:
        if df[col].dtype != 'object':
            print(df[col].describe())
            plt.figure(figsize=(12,5))
            plt.title("Distribution of "+col)
            ax = sns.distplot(df[col].dropna())
            plt.tight_layout()
            plt.show()

# %%
quality_report(train)
# Out:
#                 Total              Percent  Nunique    Dtype
# form_field40    43729              78.0875     9848  float64
# form_field31    39408              70.3714      394  float64
# form_field41    38229              68.2661    14375  float64
# form_field11    31421              56.1089     9508  float64
# form_field45    31317              55.9232        6  float64
# form_field23    28123              50.2196    16619  float64
# form_field30    25509              45.5518      274  float64
# form_field35    23148              41.3357       11  float64
# form_field15    22475              40.1339    23783  float64
# form_field48    20889              37.3018    32115  float64
# form_field22    20400              36.4286    23583  float64
# form_field46    15904              28.4000        6  float64
# form_field21    15854              28.3107    11101  float64
# form_field8     13360              23.8571    12820  float64
# form_field6     13360              23.8571     5846  float64
# form_field24    13297              23.7446    12571  float64
# form_field16    13036              23.2786       11  float64
# form_field17    11151              19.9125       15  float64
# form_field50    11056              19.7429    44746  float64
# form_field18    10402              18.5750       16  float64
# form_field12     9895              17.6696    16778  float64
# form_field27     9299              16.6054      558  float64
# form_field9      8008              14.3000    22650  float64
# form_field26     7438              13.2821      594  float64
# form_field13     5889              10.5161    21960  float64
# form_field32     5450               9.7321     2620  float64
# form_field37     5450               9.7321       52  float64
# form_field25     5450               9.7321     5014  float64
# form_field44     5383               9.6125    33238  float64
# form_field7      5163               9.2196    23199  float64
# form_field39     4211               7.5196       15  float64
# form_field2      3844               6.8643    20015  float64
# form_field1      2529               4.5161      449  float64
# form_field36     1995               3.5625       66  float64
# form_field42     1323               2.3625      986  float64
# form_field33     1256               2.2429      554  float64
# form_field43      568               1.0143       59  float64
# form_field38      355               0.6339       58  float64
# form_field4       355               0.6339     2927  float64
# form_field28      355               0.6339       95  float64
# form_field29      355               0.6339      654  float64
# form_field49      355               0.6339    13207  float64
# form_field34      355               0.6339       18  float64
# form_field10      355               0.6339    30942  float64
# form_field20      355               0.6339       27  float64
# form_field3       355               0.6339    14617  float64
# form_field5       355               0.6339     2991  float64
# form_field19        4               0.0071       26  float64
# form_field47        0               0.0000        2   object
# form_field14        0               0.0000     1237    int64
# default_status      0               0.0000        2   object

# %%
test['default_status'] = 'test' #for easy separation

# Combine train and test to avoid repetition
data = pd.concat([train, test])

# %%
data.head()
# Out:
#                        form_field1          form_field2          form_field3  \
# Applicant_ID
# Apcnt_1000000           3,436.0000               0.2851               1.6560
# Apcnt_1000004           3,456.0000               0.6740               0.2342
# Apcnt_1000008           3,276.0000               0.5384               3.1510
# Apcnt_1000012           3,372.0000               0.1701               0.5050
# Apcnt_1000016           3,370.0000               0.7727               1.1010
#
#                        form_field4          form_field5          form_field6  \
# Applicant_ID
# Apcnt_1000000               0.0000               0.0000               0.0000
# Apcnt_1000004               0.0000               0.0000               0.0000
# Apcnt_1000008               0.0000               6.2820                  nan
# Apcnt_1000012               0.0000               0.0000         192,166.0000
# Apcnt_1000016               0.0000               0.0000           1,556.0000
#
#                        form_field7          form_field8          form_field9  \
# Applicant_ID
# Apcnt_1000000      10,689,720.0000         252,072.0000       4,272,776.0000
# Apcnt_1000004         898,979.0000         497,531.0000       9,073,814.0000
# Apcnt_1000008         956,940.0000                  nan         192,944.0000
# Apcnt_1000012       3,044,703.0000         385,499.0000       3,986,472.0000
# Apcnt_1000016         214,728.0000         214,728.0000       1,284,089.0000
#
#                       form_field10         form_field11         form_field12  \
# Applicant_ID
# Apcnt_1000000      11,333,126.0000       4,397,256.0000       2,301,324.0000
# Apcnt_1000004       2,533,168.0000         244,292.0000       3,982,971.0000
# Apcnt_1000008       1,079,864.0000                  nan                  nan
# Apcnt_1000012       3,621,979.0000                  nan         771,776.0000
# Apcnt_1000016         361,770.0000         396,391.0000         818,456.0000
#
#                       form_field13  form_field14         form_field15  \
# Applicant_ID
# Apcnt_1000000       7,875,694.0000      96375139     112,181,765.0000
# Apcnt_1000004       2,141,445.0000      28141427      45,169,902.0000
# Apcnt_1000008               0.0000      16576457      22,452,691.0000
# Apcnt_1000012       1,186,839.0000      48187375     136,297,820.0000
# Apcnt_1000016         511,535.0000      28141427      15,292,757.0000
#
#                       form_field16         form_field17         form_field18  \
# Applicant_ID
# Apcnt_1000000               1.0000               1.0000               1.0000
# Apcnt_1000004               1.0000               1.0000               1.0000
# Apcnt_1000008                  nan                  nan                  nan
# Apcnt_1000012               0.0000               0.0000               0.0000
# Apcnt_1000016               0.0000               0.0000               0.0000
#
#                       form_field19         form_field20         form_field21  \
# Applicant_ID
# Apcnt_1000000               3.0000               3.0000             134.6550
# Apcnt_1000004               2.0000               2.0000             109.2300
# Apcnt_1000008               0.0000               0.0000                  nan
# Apcnt_1000012               1.0000               1.0000             120.1200
# Apcnt_1000016               3.0000               3.0000             104.5350
#
#                       form_field22         form_field23         form_field24  \
# Applicant_ID
# Apcnt_1000000                  nan                  nan             134.6550
# Apcnt_1000004          11,385.2400          14,584.2900              86.6850
# Apcnt_1000008                  nan                  nan                  nan
# Apcnt_1000012           8,580.0000               0.0000              85.8000
# Apcnt_1000016           8,360.1900          10,326.4500             115.3350
#
#                       form_field25         form_field26         form_field27  \
# Applicant_ID
# Apcnt_1000000           4,000.5000          17,064.0000          11,376.0000
# Apcnt_1000004           4,161.0000          13,413.0000           8,942.0000
# Apcnt_1000008           1,597.5000           4,746.0000           3,164.0000
# Apcnt_1000012           1,701.0000           4,014.0000           2,676.0000
# Apcnt_1000016           1,551.0000           3,285.0000           2,190.0000
#
#                       form_field28         form_field29         form_field30  \
# Applicant_ID
# Apcnt_1000000              60.0000          17,064.0000           5,962.0000
# Apcnt_1000004             304.0000          13,413.0000           5,780.0000
# Apcnt_1000008              60.0000          15,696.0000                  nan
# Apcnt_1000012              60.0000          11,679.0000                  nan
# Apcnt_1000016              60.0000          19,437.0000          12,958.0000
#
#                       form_field31         form_field32         form_field33  \
# Applicant_ID
# Apcnt_1000000                  nan           1,052.0000               8.0000
# Apcnt_1000004                  nan           2,554.0000              17.5000
# Apcnt_1000008          14,508.0000              70.0000               0.6666
# Apcnt_1000012                  nan             522.0000               7.8334
# Apcnt_1000016           5,202.0000             272.0000               1.0000
#
#                       form_field34         form_field35         form_field36  \
# Applicant_ID
# Apcnt_1000000               2.0000                  nan              12.0000
# Apcnt_1000004               0.0000               0.0000              16.0000
# Apcnt_1000008               0.0000                  nan              12.0000
# Apcnt_1000012               1.0000               1.0000               4.0000
# Apcnt_1000016               0.0000               0.0000              24.0000
#
#                       form_field37         form_field38         form_field39  \
# Applicant_ID
# Apcnt_1000000              12.0000               4.0000               0.0000
# Apcnt_1000004              24.0000               8.0000               0.0000
# Apcnt_1000008               0.0000               6.0000               0.0000
# Apcnt_1000012               8.0000               4.0000               1.0000
# Apcnt_1000016               2.0000              24.0000               0.0000
#
#                       form_field40         form_field41         form_field42  \
# Applicant_ID
# Apcnt_1000000                  nan                  nan               0.3929
# Apcnt_1000004                  nan                  nan               0.3143
# Apcnt_1000008             149.6805                  nan               0.1630
# Apcnt_1000012                  nan                  nan               0.4889
# Apcnt_1000016             150.0135                  nan               0.2750
#
#                       form_field43         form_field44         form_field45  \
# Applicant_ID
# Apcnt_1000000               2.0200               0.7116               0.0000
# Apcnt_1000004               8.0800               0.1836                  nan
# Apcnt_1000008              18.1800               0.7911               0.0000
# Apcnt_1000012               2.0200               0.6852                  nan
# Apcnt_1000016              12.1200               0.4382               0.0000
#
#                       form_field46 form_field47         form_field48  \
# Applicant_ID
# Apcnt_1000000               0.0000       charge                  nan
# Apcnt_1000004               0.0000       charge             349.8057
# Apcnt_1000008               0.0000       charge                  nan
# Apcnt_1000012               0.0000       charge              89.9401
# Apcnt_1000016               0.0000       charge              97.8875
#
#                       form_field49         form_field50 default_status
# Applicant_ID
# Apcnt_1000000               1.1295               0.0443             no
# Apcnt_1000004               1.6205               0.3224             no
# Apcnt_1000008               1.5134               0.0116            yes
# Apcnt_1000012               0.6645               0.0827             no
# Apcnt_1000016               1.4279               0.0456             no

# %%
print('Combined dataset has {} entries and {} features'.format(data.shape[0], data.shape[1]))
# Out:
# Combined dataset has 80000 entries and 51 features

# %%
missing_col = data.columns[data.isna().any()]
missing_col
# Out:
# Index(['form_field1', 'form_field2', 'form_field3', 'form_field4',
#        'form_field5', 'form_field6', 'form_field7', 'form_field8',
#        'form_field9', 'form_field10', 'form_field11', 'form_field12',
#        'form_field13', 'form_field15', 'form_field16', 'form_field17',
#        'form_field18', 'form_field19', 'form_field20', 'form_field21',
#        'form_field22', 'form_field23', 'form_field24', 'form_field25',
#        'form_field26', 'form_field27', 'form_field28', 'form_field29',
#        'form_field30', 'form_field31', 'form_field32', 'form_field33',
#        'form_field34', 'form_field35', 'form_field36', 'form_field37',
#        'form_field38', 'form_field39', 'form_field40', 'form_field41',
#        'form_field42', 'form_field43', 'form_field44', 'form_field45',
#        'form_field46', 'form_field48', 'form_field49', 'form_field50'],
#       dtype='object')

# %%
for col in missing_col:
    
    data[col].fillna(data[col].mean(), inplace = True)

# %%
missing_col = data.columns[data.isna().any()]
missing_col
# Out:
# Index([], dtype='object')

# %%
quality_report(data)
# Out:
#                 Total              Percent  Nunique    Dtype
# default_status      0               0.0000        3   object
# form_field13        0               0.0000    27226  float64
# form_field23        0               0.0000    22455  float64
# form_field22        0               0.0000    32337  float64
# form_field21        0               0.0000    11797  float64
# form_field20        0               0.0000       29  float64
# form_field19        0               0.0000       27  float64
# form_field18        0               0.0000       17  float64
# form_field17        0               0.0000       16  float64
# form_field16        0               0.0000       13  float64
# form_field15        0               0.0000    33070  float64
# form_field14        0               0.0000     1566    int64
# form_field12        0               0.0000    20079  float64
# form_field25        0               0.0000     5426  float64
# form_field11        0               0.0000    11544  float64
# form_field10        0               0.0000    39640  float64
# form_field9         0               0.0000    29579  float64
# form_field8         0               0.0000    15705  float64
# form_field7         0               0.0000    28565  float64
# form_field6         0               0.0000     7118  float64
# form_field5         0               0.0000     4031  float64
# form_field4         0               0.0000     3695  float64
# form_field3         0               0.0000    18303  float64
# form_field2         0               0.0000    24696  float64
# form_field24        0               0.0000    14050  float64
# form_field26        0               0.0000      620  float64
# form_field50        0               0.0000    63789  float64
# form_field39        0               0.0000       16  float64
# form_field49        0               0.0000    18181  float64
# form_field48        0               0.0000    45306  float64
# form_field47        0               0.0000        2   object
# form_field46        0               0.0000        9  float64
# form_field45        0               0.0000        7  float64
# form_field44        0               0.0000    42701  float64
# form_field43        0               0.0000       60  float64
# form_field42        0               0.0000     1085  float64
# form_field41        0               0.0000    19478  float64
# form_field40        0               0.0000    13624  float64
# form_field38        0               0.0000       62  float64
# form_field27        0               0.0000      579  float64
# form_field37        0               0.0000       56  float64
# form_field36        0               0.0000       71  float64
# form_field35        0               0.0000       12  float64
# form_field34        0               0.0000       19  float64
# form_field33        0               0.0000      576  float64
# form_field32        0               0.0000     2838  float64
# form_field31        0               0.0000      413  float64
# form_field30        0               0.0000      280  float64
# form_field29        0               0.0000      669  float64
# form_field28        0               0.0000       98  float64
# form_field1         0               0.0000      455  float64

# %%
train = data[:56000]
test = data[56000:]

# %%
exp_clf = setup(train, target = 'default_status', train_size = 0.7, normalize = True)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_c5edbc62_f415_11ea_aac3_0242ac1c0002row15_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row0_col1" class="data row0 col1" >6180</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row2_col1" class="data row2 col1" >no: 0, yes: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row3_col1" class="data row3 col1" >(56000, 51)</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row5_col1" class="data row5 col1" >49</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row6_col1" class="data row6 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row10_col1" class="data row10 col1" >(56000, 51)</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row11_col1" class="data row11 col1" >(39199, 51)</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row12_col1" class="data row12 col1" >(16801, 51)</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row15_col1" class="data row15 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row16_col1" class="data row16 col1" >zscore</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_c5edbc62_f415_11ea_aac3_0242ac1c0002row18_col0" class="data row18 col0" >Transformation Method </td>

# %%
compare_models(sort = 'AUC')
# Out:
# <style  type="text/css" >
#     #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002 th {
#           text-align: left;
#     }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row0_col0 {
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row0_col7 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row0_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row1_col0 {
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row1_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row1_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row1_col7 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row1_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row2_col0 {
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row2_col7 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row2_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row3_col0 {
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row3_col7 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row3_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row4_col0 {
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row4_col7 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row4_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row5_col0 {
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row5_col7 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row5_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row6_col0 {
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row6_col7 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row6_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row7_col0 {
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2d73ab3c_f419_11ea_aac3_0242ac1c0002row7_col6 {
#             : ;
#             text

# %%
base_model = create_model('catboost', fold = 10, cross_validation = True)
# Out:
# <style  type="text/css" >
#     #T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row10_col0 {
#             background:  yellow;
#         }    #T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row10_col1 {
#             background:  yellow;
#         }    #T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row10_col2 {
#             background:  yellow;
#         }    #T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row10_col3 {
#             background:  yellow;
#         }    #T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row10_col4 {
#             background:  yellow;
#         }    #T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row10_col5 {
#             background:  yellow;
#         }    #T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row10_col6 {
#             background:  yellow;
#         }</style><table id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row0_col0" class="data row0 col0" >0.8051</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row0_col1" class="data row0 col1" >0.8371</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row0_col2" class="data row0 col2" >0.4333</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row0_col3" class="data row0 col3" >0.6541</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row0_col4" class="data row0 col4" >0.5213</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row0_col5" class="data row0 col5" >0.4052</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row0_col6" class="data row0 col6" >0.4188</td>
#             </tr>
#             <tr>
#                         <th id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row1_col0" class="data row1 col0" >0.8071</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row1_col1" class="data row1 col1" >0.8285</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row1_col2" class="data row1 col2" >0.4396</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row1_col3" class="data row1 col3" >0.6594</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row1_col4" class="data row1 col4" >0.5275</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row1_col5" class="data row1 col5" >0.4124</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row1_col6" class="data row1 col6" >0.4258</td>
#             </tr>
#             <tr>
#                         <th id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row2_col0" class="data row2 col0" >0.8061</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row2_col1" class="data row2 col1" >0.8407</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row2_col2" class="data row2 col2" >0.4479</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row2_col3" class="data row2 col3" >0.6515</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row2_col4" class="data row2 col4" >0.5309</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row2_col5" class="data row2 col5" >0.4139</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row2_col6" class="data row2 col6" >0.4255</td>
#             </tr>
#             <tr>
#                         <th id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row3_col0" class="data row3 col0" >0.8084</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row3_col1" class="data row3 col1" >0.8345</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row3_col2" class="data row3 col2" >0.4521</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row3_col3" class="data row3 col3" >0.6586</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row3_col4" class="data row3 col4" >0.5361</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row3_col5" class="data row3 col5" >0.4206</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row3_col6" class="data row3 col6" >0.4324</td>
#             </tr>
#             <tr>
#                         <th id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row4_col0" class="data row4 col0" >0.8097</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row4_col1" class="data row4 col1" >0.8407</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row4_col2" class="data row4 col2" >0.4542</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row4_col3" class="data row4 col3" >0.6626</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row4_col4" class="data row4 col4" >0.5389</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row4_col5" class="data row4 col5" >0.4243</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row4_col6" class="data row4 col6" >0.4363</td>
#             </tr>
#             <tr>
#                         <th id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row5_col0" class="data row5 col0" >0.8046</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row5_col1" class="data row5 col1" >0.8379</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row5_col2" class="data row5 col2" >0.4458</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row5_col3" class="data row5 col3" >0.6465</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row5_col4" class="data row5 col4" >0.5277</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row5_col5" class="data row5 col5" >0.4097</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row5_col6" class="data row5 col6" >0.4210</td>
#             </tr>
#             <tr>
#                         <th id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row6_col0" class="data row6 col0" >0.8023</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row6_col1" class="data row6 col1" >0.8323</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row6_col2" class="data row6 col2" >0.4250</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row6_col3" class="data row6 col3" >0.6466</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row6_col4" class="data row6 col4" >0.5129</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0242ac1c0002row6_col5" class="data row6 col5" >0.3954</td>
#                         <td id="T_e2f1bb34_f419_11ea_aac3_0

# %%
tuned_model = tune_model(base_model,  fold = 10, optimize="AUC")
# Out:
# <style  type="text/css" >
#     #T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row10_col0 {
#             background:  yellow;
#         }    #T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row10_col1 {
#             background:  yellow;
#         }    #T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row10_col2 {
#             background:  yellow;
#         }    #T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row10_col3 {
#             background:  yellow;
#         }    #T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row10_col4 {
#             background:  yellow;
#         }    #T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row10_col5 {
#             background:  yellow;
#         }    #T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row10_col6 {
#             background:  yellow;
#         }</style><table id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row0_col0" class="data row0 col0" >0.8054</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row0_col1" class="data row0 col1" >0.8398</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row0_col2" class="data row0 col2" >0.4292</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row0_col3" class="data row0 col3" >0.6571</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row0_col4" class="data row0 col4" >0.5192</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row0_col5" class="data row0 col5" >0.4039</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row0_col6" class="data row0 col6" >0.4183</td>
#             </tr>
#             <tr>
#                         <th id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row1_col0" class="data row1 col0" >0.8028</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row1_col1" class="data row1 col1" >0.8288</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row1_col2" class="data row1 col2" >0.4312</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row1_col3" class="data row1 col3" >0.6459</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row1_col4" class="data row1 col4" >0.5172</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row1_col5" class="data row1 col5" >0.3994</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row1_col6" class="data row1 col6" >0.4123</td>
#             </tr>
#             <tr>
#                         <th id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row2_col0" class="data row2 col0" >0.8082</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row2_col1" class="data row2 col1" >0.8397</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row2_col2" class="data row2 col2" >0.4396</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row2_col3" class="data row2 col3" >0.6635</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row2_col4" class="data row2 col4" >0.5288</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row2_col5" class="data row2 col5" >0.4146</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row2_col6" class="data row2 col6" >0.4284</td>
#             </tr>
#             <tr>
#                         <th id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row3_col0" class="data row3 col0" >0.8084</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row3_col1" class="data row3 col1" >0.8346</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row3_col2" class="data row3 col2" >0.4469</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row3_col3" class="data row3 col3" >0.6610</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row3_col4" class="data row3 col4" >0.5333</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row3_col5" class="data row3 col5" >0.4183</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row3_col6" class="data row3 col6" >0.4310</td>
#             </tr>
#             <tr>
#                         <th id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row4_col0" class="data row4 col0" >0.8087</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row4_col1" class="data row4 col1" >0.8399</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row4_col2" class="data row4 col2" >0.4583</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row4_col3" class="data row4 col3" >0.6567</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row4_col4" class="data row4 col4" >0.5399</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row4_col5" class="data row4 col5" >0.4239</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row4_col6" class="data row4 col6" >0.4348</td>
#             </tr>
#             <tr>
#                         <th id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row5_col0" class="data row5 col0" >0.8015</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row5_col1" class="data row5 col1" >0.8362</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row5_col2" class="data row5 col2" >0.4323</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row5_col3" class="data row5 col3" >0.6404</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row5_col4" class="data row5 col4" >0.5162</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row5_col5" class="data row5 col5" >0.3972</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row5_col6" class="data row5 col6" >0.4093</td>
#             </tr>
#             <tr>
#                         <th id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row6_col0" class="data row6 col0" >0.8018</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row6_col1" class="data row6 col1" >0.8345</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row6_col2" class="data row6 col2" >0.4198</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row6_col3" class="data row6 col3" >0.6469</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row6_col4" class="data row6 col4" >0.5092</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0242ac1c0002row6_col5" class="data row6 col5" >0.3920</td>
#                         <td id="T_d2a8b5d8_f41a_11ea_aac3_0

# %%
predictions = predict_model(tuned_model)
# Out:
#                  Model  ...                  MCC
# 0  CatBoost Classifier  ...               0.4321
#
# [1 rows x 8 columns]

# %%
finalize_model(tuned_model)

# %%
test.drop("default_status", axis = 1, inplace = True)

# %%
predictions = predict_model(tuned_model, data=test)
predictions.head()
# Out:
#                        form_field1  ...                Score
# Apcnt_1000032           3,236.0000  ...                  nan
# Apcnt_1000048           3,284.0000  ...                  nan
# Apcnt_1000052           3,491.9422  ...                  nan
# Apcnt_1000076           3,232.0000  ...                  nan
# Apcnt_1000080           3,466.0000  ...                  nan
#
# [5 rows x 52 columns]

# %%
predictions.shape
# Out:
# (48000, 52)

# %%
sample['default_status'] = predictions['Score']
sample.to_csv('submission.csv',index=False)
sample.head()
# Out:
#     Applicant_ID       default_status
# 0  Apcnt_1000032               0.3079
# 1  Apcnt_1000048               0.3842
# 2  Apcnt_1000052               0.2964
# 3  Apcnt_1000076               0.7527
# 4  Apcnt_1000080               0.2314
